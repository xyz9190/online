# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import random

# %%
mnist = tf.keras.datasets.mnist  
(x_train, y_train), (x_test, y_test) = mnist. load_data()

# %%
x_train = x_train / 255
x_test = x_test/255

# %%
model = keras.Sequential([
keras.layers.Flatten(input_shape=(28, 28)),
keras.layers. Dense(128, activation="relu"),
keras.layers.Dense(10, activation="softmax")
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 128)               100480
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 101770 (397.54 KB)
# Trainable params: 101770 (397.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer="sgd",
loss="sparse_categorical_crossentropy",
metrics=['accuracy'])

# %%
history=model.fit(x_train,
y_train, validation_data=(x_test,y_test), epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 11s 5ms/step - loss: 0.6453 - accuracy: 0.8369 - val_loss: 0.3587 - val_accuracy: 0.9018
# Epoch 2/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.3408 - accuracy: 0.9050 - val_loss: 0.2979 - val_accuracy: 0.9151
# Epoch 3/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.2942 - accuracy: 0.9169 - val_loss: 0.2729 - val_accuracy: 0.9227
# Epoch 4/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.2658 - accuracy: 0.9249 - val_loss: 0.2453 - val_accuracy: 0.9306
# Epoch 5/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.2433 - accuracy: 0.9310 - val_loss: 0.2259 - val_accuracy: 0.9358
# Epoch 6/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.2249 - accuracy: 0.9369 - val_loss: 0.2108 - val_accuracy: 0.9400
# Epoch 7/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.2088 - accuracy: 0.9407 - val_loss: 0.1986 - val_accuracy: 0.9439
# Epoch 8/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.1951 - accuracy: 0.9453 - val_loss: 0.1865 - val_accuracy: 0.9467
# Epoch 9/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.1830 - accuracy: 0.9483 - val_loss: 0.1758 - val_accuracy: 0.9495
# Epoch 10/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.1721 - accuracy: 0.9517 - val_loss: 0.1681 - val_accuracy: 0.9514

# %%
test_loss, test_acc=model.evaluate(x_test,y_test)
print("Loss=%.3f" %test_loss)
print("Accuracy=%.3f" %test_acc)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.1681 - accuracy: 0.9514
# Loss=0.168
# Accuracy=0.951

# %%
n=random.randint(0,9999)
plt.imshow(x_test[n])
plt.show()
predicted_value=model.predict(x_test)
plt.imshow(x_test[n])
plt.show()
# Out:
# 313/313 [==============================] - 1s 4ms/step

# %%
print('Predicted Value: ', predicted_value[n])
# Out:
# Predicted Value:  [9.9987626e-01 2.2130961e-10 8.5300671e-05 2.1495991e-05 4.2635957e-09
#  1.3962025e-05 9.3656354e-08 7.2878180e-08 2.4290052e-06 4.1727887e-07]

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy') 
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss') 
plt.ylabel('Loss')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
